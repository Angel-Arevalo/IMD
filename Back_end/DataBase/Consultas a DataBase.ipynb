# %%
import sqlite3 as sql
import pandas as pd 

Apuntador = sql.connect(r'DataUsers.db')

# %%
Apuntador.execute('''
CREATE TABLE IF NOT EXISTS Usuarios (Nombre_Usuario TEXT,
                   Contraseña TEXT, Rol TEXT, Email TEXT);''')

# %%
Apuntador.execute("INSERT INTO Usuarios (Nombre_Usuario, Contraseña, Rol) VALUES ('Angel','Arevalo','erv')")

# %%
df = pd.read_sql_query("SELECT * FROM Usuarios;", Apuntador)

# %%
df
# Out:
#    Nombre_Usuario           Contraseña                 Rol         Email
# 0           Angel              Arevalo                 erv          None
# 1           Angel             12345678  {'0': {}, '1': {}}          None
# 2           Angel            r1234790'                None          None
# 3           Angel            r1234790'                None          None
# 4           Angel             12345678                None          None
# 5           Angel             12345678                None          None
# 6           Angel             ;<=>?@AB                None          None
# 7           Angel              Arevalo                 erv          None
# 8           Angel             ;<=>?@AB  {'0': {}, '1': {}}          None
# 9           Angel             ;<=>?@AB  {'0': {}, '1': {}}          None
# 10          Angel       K|okvyk}qoq                None          None
# 11          Angel       K|okvyk}qoq                None          None
# 12          Angel             ;<=>?@AB  {'0': {}, '1': {}}  ejemplo@unal
# 13          Angel             ;<=>?@AB          Estudiante      ejemplo@
# 14          Angel             EFGHIJKL                None          None
# 15          Angel             EFGHIJKL                None          None
# 16          Angel             EFGHIJKL                None          None
# 17          Angel             EFGHIJKL                None          None
# 18          Angel             EFGHIJKL                None          None
# 19          Angel             EFGHIJKL                None          None
# 20          Angel             EFGHIJKL                None          None
# 21          Angel             EFGHIJKL                None          None
# 22          Angel             EFGHIJKL                None          None
# 23          Angel             EFGHIJKL                None          None
# 24          Angel             EFGHIJKL                None          None
# 25          Angel             EFGHIJKL                None          None
# 26          Angel             EFGHIJKL                None          None
# 27         sdgash           ;<=>?@ABC:                None          None
# 28          Angel             ;<=>?@AB                None          None
# 29          Angel             ;<=>?@AC                None          None
# 30         sdgash       K|okvyk}qoq                None          None
# 31          Angel             ;<=>?@AB                None          None
# 32          Angel             ;<=>?@AB                None          None
# 33          Angel             ;<=>?@AB                None          None
# 34          Angel             ;<=>?@AB                None          None
# 35          Angel             ;<=>?@AB                None          None
# 36          Angel             ;<=>?@AB                None          None
# 37          Angel             ;<=>?@AB                None          None
# 38          Angel             ;<=>?@AB                None          None
# 39          Angel             ;<=>?@AB                None          None
# 40          Angel             ;<=>?@AB                None          None
# 41          Angel             ;<=>?@AB                None          None
# 42          Angel             ;<=>?@AB                None          None
# 43          Angel             ;<=>?@AB                None          None
# 44          Angel             ;<=>?@AB                None          None
# 45          Angel             ;<=>?@AB                None          None
# 46          Angel             ;<=>?@AB                None          None
# 47          Angel             ;<=>?@AB                None          None
# 48          Angel             ;<=>?@AB                None          None
# 49          Angel            ;<=>?@ABC                None          None
# 50          Angel  k}npqrtu{zl{osp                None          None
# 51          Angel  k}npqrtu{zl{osp                None          None
# 52           Ange  k}npqrtu{zl{osp                None          None

# %%
Apuntador.commit()
Apuntador.close()
